# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Problem parameters

# %%
states = ["Tiger left","Tiger right"] # States
actions = ["Open left","Open right","Listen"] # Actions
observations = ["observe tiger left","observe tiger right"] # Observations
belief_initial = [0.5,0.5]
gamma = 0.85 # Discount factor
t = 5 # Horizon

# %%
# Transition probabilities
T =  np.array([[[0.5,0.5,1], # Tiger left -> Tiger left
               [0.5,0.5,0]], # Tiger left -> Tiger right
              [[0.5,0.5,0], # Tiger right -> Tiger left
              [0.5,0.5,1]], # Tiger right -> Tiger right
              ])

# %%
# Observation probabilities [observation][state][action]
O = np.array([[[0.5, 0.5, 0.85], # Tiger left -> Tiger left
               [0.5,0.5, 0.15]], # Tiger left -> Tiger right
              [[0.5,0.5, 0.15], # Tiger right -> Tiger left
              [0.5,0.5, 0.85]], # Tiger right -> Tiger right
             ])

# %%
# Reward
R = np.array([[-100,10,-1],[10,-100,-1]])
reward_list = []

# %% [markdown]
# # Class definition

# %%
class tiger_problem:

    def  __init__(self, horizon, states, actions, observations, belief_intial, gamma, tran_matrix, obs_matrix, R_func):
        self.horizon = horizon
        self.states = states
        self.actions = actions
        self.observations = observations
        self.b_init = belief_initial
        self.tran_matrix = tran_matrix
        self.obs_matrix = obs_matrix
        self.R_func = R_func
        self.gamma = gamma

    # Function to update belief
    def belief_update(self, action, obs, b):
        b_new = [0,0]
        for sj in range(len(states)):
            pr_obs = self.obs_matrix[obs][sj][action]
            summation = 0.0
            for si in range(len(states)):
                pr_s_prime = self.tran_matrix[sj][si][action]
                summation += pr_s_prime * b[si]
            b_new[sj] = (pr_obs * summation)

        # Normalising to ensure probabilities sum to 1
        total = sum(b_new)
        b_new = [x / total for x in b_new]
        print("New belief: ",b_new)
        return b_new

    # Value Iteration
    def value(self,b,k):
        if k == self.horizon:
            return 0
        if (k < self.horizon):
            Vmax = -10000
            rw_exp_vec = np.matmul(b,R)
            for a in range(len(actions)):
                value_future = 0
                print("Action: ",a)
                rw_exp = rw_exp_vec[a]
                print("Expected reward: ", rw_exp)
                reward_list.append(rw_exp)
                for obs in range(len(observations)):
                    b_new = self.belief_update(a, obs, b)
                    v_b_new=self.value(b_new, k+1)
                    for sj in range(len(states)):
                        for si in range(len(states)):
                            value_future += b[si]*self.tran_matrix[sj][si][a]*self.obs_matrix[obs][si][a]*v_b_new
                Value = (rw_exp + gamma*value_future)
                print("Depth: ", k, " Action: ", actions[a])
                print("Value: ", Value, " Reward: ", rw_exp, " Next value: ", value_future)
                print("********************************************************************")

                if Value > Vmax:
                    a_max = a
                    Vmax = Value

        print()
        print("Depth: ", k, " Action: ", actions[a])
        print("V_max: ", Vmax)
        print("Optimal action: ", actions[a_max])
        return Vmax

# %% [markdown]
# # Evaluation

# %%
tiger = tiger_problem(t,states,actions,observations,belief_initial,gamma,T,O,R)
print(tiger.value(belief_initial,0))
# Out:
# Streaming output truncated to the last 5000 lines.
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# Action:  0
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9697986577181208, 0.0302013422818792]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.15, 0.85]
# Action:  0
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.5, 0.5]
# New belief:  [0.0302013422818792, 0.9697986577181208]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Listen
# Value:  -1.85  Reward:  -1.0  Next value:  -1.0
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  -1.85
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# Action:  0
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9697986577181208, 0.0302013422818792]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.15, 0.85]
# Action:  0
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.5, 0.5]
# New belief:  [0.0302013422818792, 0.9697986577181208]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Listen
# Value:  -1.85  Reward:  -1.0  Next value:  -1.0
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  -1.85
# Optimal action:  Listen
# Depth:  2  Action:  Open right
# Value:  -46.5725  Reward:  -45.0  Next value:  -1.8499999999999999
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# Action:  0
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  -84.35  Reward:  -83.5  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -7.35  Reward:  -6.5  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9697986577181208, 0.0302013422818792]
# Action:  0
# Expected reward:  -96.6778523489933
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -96.6778523489933  Reward:  -96.6778523489933  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  6.677852348993288
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  6.677852348993288  Reward:  6.677852348993288  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9945344129554656, 0.005465587044534414]
# New belief:  [0.85, 0.15000000000000002]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  6.677852348993288
# Optimal action:  Open right
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Listen
# Value:  3.0119999999999987  Reward:  -1.0  Next value:  4.719999999999999
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  3.0119999999999987
# Optimal action:  Listen
# New belief:  [0.15, 0.85]
# Action:  0
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  -7.35  Reward:  -6.5  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -84.35  Reward:  -83.5  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.0302013422818792, 0.9697986577181208]
# Action:  0
# Expected reward:  6.677852348993288
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  6.677852348993288  Reward:  6.677852348993288  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -96.6778523489933
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -96.6778523489933  Reward:  -96.6778523489933  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.15000000000000002, 0.85]
# New belief:  [0.005465587044534414, 0.9945344129554656]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  6.677852348993288
# Optimal action:  Open left
# Depth:  3  Action:  Listen
# Value:  3.0119999999999996  Reward:  -1.0  Next value:  4.72
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  3.0119999999999996
# Optimal action:  Listen
# Depth:  2  Action:  Listen
# Value:  1.5601999999999991  Reward:  -1.0  Next value:  3.011999999999999
# ********************************************************************
#
# Depth:  2  Action:  Listen
# V_max:  1.5601999999999991
# Optimal action:  Listen
# Depth:  1  Action:  Open left
# Value:  -5.173830000000001  Reward:  -6.5  Next value:  1.5601999999999991
# ********************************************************************
# Action:  1
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# Action:  0
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9697986577181208, 0.0302013422818792]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.15, 0.85]
# Action:  0
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.5, 0.5]
# New belief:  [0.0302013422818792, 0.9697986577181208]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Listen
# Value:  -1.85  Reward:  -1.0  Next value:  -1.0
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  -1.85
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# Action:  0
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9697986577181208, 0.0302013422818792]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.15, 0.85]
# Action:  0
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.5, 0.5]
# New belief:  [0.0302013422818792, 0.9697986577181208]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Listen
# Value:  -1.85  Reward:  -1.0  Next value:  -1.0
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  -1.85
# Optimal action:  Listen
# Depth:  2  Action:  Open left
# Value:  -46.5725  Reward:  -45.0  Next value:  -1.8499999999999999
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# Action:  0
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9697986577181208, 0.0302013422818792]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.15, 0.85]
# Action:  0
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.5, 0.5]
# New belief:  [0.0302013422818792, 0.9697986577181208]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Listen
# Value:  -1.85  Reward:  -1.0  Next value:  -1.0
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  -1.85
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# Action:  0
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9697986577181208, 0.0302013422818792]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.15, 0.85]
# Action:  0
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.5, 0.5]
# New belief:  [0.0302013422818792, 0.9697986577181208]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Listen
# Value:  -1.85  Reward:  -1.0  Next value:  -1.0
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  -1.85
# Optimal action:  Listen
# Depth:  2  Action:  Open right
# Value:  -46.5725  Reward:  -45.0  Next value:  -1.8499999999999999
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# Action:  0
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  -84.35  Reward:  -83.5  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -7.35  Reward:  -6.5  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9697986577181208, 0.0302013422818792]
# Action:  0
# Expected reward:  -96.6778523489933
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -96.6778523489933  Reward:  -96.6778523489933  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  6.677852348993288
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  6.677852348993288  Reward:  6.677852348993288  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9945344129554656, 0.005465587044534414]
# New belief:  [0.85, 0.15000000000000002]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  6.677852348993288
# Optimal action:  Open right
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# ...
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -45.85  Reward:  -45.0  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# Action:  0
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.9697986577181208, 0.0302013422818792]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.15, 0.85]
# Action:  0
# Expected reward:  -6.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -6.5  Reward:  -6.5  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -83.5  Reward:  -83.5  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.5, 0.5]
# New belief:  [0.0302013422818792, 0.9697986577181208]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Listen
# Value:  -1.85  Reward:  -1.0  Next value:  -1.0
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  -1.85
# Optimal action:  Listen
# Depth:  2  Action:  Open right
# Value:  -98.2503523489933  Reward:  -96.6778523489933  Next value:  -1.85
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.15000000000000002, 0.85]
# Action:  0
# Expected reward:  -6.500000000000002
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  -7.350000000000001  Reward:  -6.500000000000002  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -83.5
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -84.35  Reward:  -83.5  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.030201342281879203, 0.9697986577181208]
# Action:  0
# Expected reward:  6.677852348993287
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  6.677852348993287  Reward:  6.677852348993287  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -96.6778523489933
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -96.6778523489933  Reward:  -96.6778523489933  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.15000000000000005, 0.85]
# New belief:  [0.005465587044534414, 0.9945344129554656]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  6.677852348993287
# Optimal action:  Open left
# Depth:  3  Action:  Listen
# Value:  3.0119999999999987  Reward:  -1.0  Next value:  4.719999999999999
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  3.0119999999999987
# Optimal action:  Listen
# New belief:  [0.005465587044534414, 0.9945344129554656]
# Action:  0
# Expected reward:  9.398785425101213
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open left
# Value:  8.548785425101213  Reward:  9.398785425101213  Next value:  -1.0
# ********************************************************************
# Action:  1
# Expected reward:  -99.39878542510122
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# New belief:  [0.5, 0.5]
# Action:  0
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -45.0
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -45.0  Reward:  -45.0  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.85, 0.15]
# New belief:  [0.15, 0.85]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  -1.0
# Optimal action:  Listen
# Depth:  3  Action:  Open right
# Value:  -100.24878542510122  Reward:  -99.39878542510122  Next value:  -1.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.030201342281879203, 0.9697986577181208]
# Action:  0
# Expected reward:  6.677852348993287
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  6.677852348993287  Reward:  6.677852348993287  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -96.6778523489933
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -96.6778523489933  Reward:  -96.6778523489933  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -1.0
# New belief:  [0.15000000000000005, 0.85]
# New belief:  [0.005465587044534414, 0.9945344129554656]
# Depth:  4  Action:  Listen
# Value:  -1.0  Reward:  -1.0  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  6.677852348993287
# Optimal action:  Open left
# New belief:  [0.0009688763426712281, 0.9990311236573287]
# Action:  0
# Expected reward:  9.893423602306164
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open left
# Value:  9.893423602306164  Reward:  9.893423602306164  Next value:  0.0
# ********************************************************************
# Action:  1
# Expected reward:  -99.89342360230616
# New belief:  [0.5, 0.5]
# New belief:  [0.5, 0.5]
# Depth:  4  Action:  Open right
# Value:  -99.89342360230616  Reward:  -99.89342360230616  Next value:  0.0
# ********************************************************************
# Action:  2
# Expected reward:  -0.9999999999999999
# New belief:  [0.005465587044534414, 0.9945344129554656]
# New belief:  [0.00017111471023167384, 0.9998288852897683]
# Depth:  4  Action:  Listen
# Value:  -0.9999999999999999  Reward:  -0.9999999999999999  Next value:  0.0
# ********************************************************************
#
# Depth:  4  Action:  Listen
# V_max:  9.893423602306164
# Optimal action:  Open left
# Depth:  3  Action:  Listen
# Value:  6.988967611336032  Reward:  -1.0  Next value:  9.398785425101215
# ********************************************************************
#
# Depth:  3  Action:  Listen
# V_max:  8.548785425101213
# Optimal action:  Open left
# Depth:  2  Action:  Listen
# Value:  5.4610325503355694  Reward:  -1.0  Next value:  7.60121476510067
# ********************************************************************
#
# Depth:  2  Action:  Listen
# V_max:  5.4610325503355694
# Optimal action:  Listen
# Depth:  1  Action:  Listen
# Value:  2.7963722124999992  Reward:  -1.0  Next value:  4.466320249999999
# ********************************************************************
#
# Depth:  1  Action:  Listen
# V_max:  2.7963722124999992
# Optimal action:  Listen
# Depth:  0  Action:  Listen
# Value:  1.376916380624999  Reward:  -1.0  Next value:  2.796372212499999
# ********************************************************************
#
# Depth:  0  Action:  Listen
# V_max:  1.376916380624999
# Optimal action:  Listen
# 1.376916380624999

# %%
reward_list[0]
# Out:
# -45.0

# %%
reward_list[-1]
# Out:
# -0.9999999999999999
